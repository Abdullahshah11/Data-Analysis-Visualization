# %%
# !pip install pandas numpy matplotlib seaborn missingno ydata-profiling

# %%
# !pip install -q pandas numpy matplotlib seaborn missingno ydata-profiling
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.3/400.3 kB 8.2 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

# %%
from ydata_profiling import ProfileReport
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_2187/44057814.py in <cell line: 0>()
# ----> 1 from ydata_profiling import ProfileReport
#
# ModuleNotFoundError: No module named 'ydata_profiling'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import pandas as pd
df = pd.read_csv("Activity 01 (Responses).csv")

# %%
profile = ProfileReport(df, title="Pandas Profiling Report")
profile
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2187/4032269723.py in <cell line: 0>()
# ----> 1 profile = ProfileReport(df, title="Pandas Profiling Report")
#       2 profile
#
# NameError: name 'ProfileReport' is not defined

# %%
df.head()
# Out:
#              Timestamp What is your age? When do you prefer to study?  \
# 0  2026-01-01 00:00:00                19                      Morning
# 1  2026-01-01 06:00:00                23                      Evening
# 2  2026-01-01 12:00:00                21                        Night
# 3  2026-01-01 18:00:00                20                      Evening
# 4  2026-01-02 00:00:00                18                        Night
#
#   How many hours do you spend on screens daily? (including phone, laptop, tablets )  \
# 0                                          5-6 hours
# 1                                          7-8 hours
# 2                                          3-4 hours
# 3                                          5-6 hours
# 4                                          5-6 hours
#
#   Do you prefer coffee or tea? Which social media app do you prefer?  \
# 0                       Coffee                               YouTube
# ...

# %%
df.shape
# Out:
# (1000, 13)

# %%
df["What is your age?"]
# Out:
# 0      19
# 1      23
# 2      21
# 3      20
# 4      18
#        ..
# 995    17
# 996    23
# 997    18
# 998    23
# 999    19
# Name: What is your age?, Length: 1000, dtype: object

# %%
print(df.columns.tolist())
# Out:
# ['Timestamp', 'What is your age?', 'When do you prefer to study?', 'How many hours do you spend on screens daily? (including phone, laptop, tablets )', 'Do you prefer coffee or tea?', 'Which social media app do you prefer?', 'What are your hobbies / interest? ', 'How many languages do you speak fluently?', 'How often do you exercise in a week?', 'How do you primarily commute to work or school?', 'How many hours of sleep do you get on an average night?', 'On average, how much water do you drink per day?', 'What is your preferred method for staying informed about current events?']

# %%
df.isnull().sum()
# Out:
# Timestamp                                                                             0
# What is your age?                                                                     0
# When do you prefer to study?                                                         35
# How many hours do you spend on screens daily? (including phone, laptop, tablets )     0
# Do you prefer coffee or tea?                                                          0
# Which social media app do you prefer?                                                 0
# What are your hobbies / interest?                                                    20
# How many languages do you speak fluently?                                             0
# How often do you exercise in a week?                                                  0
# How do you primarily commute to work or school?                                       0
# How many hours of sleep do you get on an average night?                               0
# ...

# %%
df["When do you prefer to study?"] = df["When do you prefer to study?"].fillna(df["When do you prefer to study?"].mode()[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2187/1214234774.py in <cell line: 0>()
# ----> 1 df["When do you prefer to study?"] = df["When do you prefer to study?"].fillna(a[0])
#
# NameError: name 'a' is not defined

# %%
import matplotlib.pyplot as plt

age_counts = df["What is your age?"].value_counts()

plt.figure(figsize=(6,4))
plt.bar(age_counts.index, age_counts.values)

plt.title("Distribution of Age")
plt.xlabel("Age Groups")
plt.ylabel("Number of Students")

plt.show()

# %%
age_counts = df["What is your age?"].value_counts()

plt.figure(figsize=(6,6))

plt.pie(
    age_counts,
    labels=age_counts.index,
    autopct="%1.1f%%"
)

plt.title("Distribution of Age")
plt.show()

# %%
plt.figure(figsize=(8,5))

plt.scatter(
    df["View Count"],
    df["Like Count"],
    marker="^"
)

plt.title("Views vs Likes")
plt.xlabel("View Count")
plt.ylabel("Like Count")

plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2187/1092641781.py in <cell line: 0>()
#       2
#       3 plt.scatter(
# ----> 4     data["View Count"],
#       5     data["Like Count"],
#       6     marker="^"
#
# NameError: name 'data' is not defined
